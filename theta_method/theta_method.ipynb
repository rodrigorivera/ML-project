# %%
import pandas as pd
import numpy as np
import sys
import numpy as np 
import pandas as pd 
import statsmodels as sm 
import warnings 
from scipy.stats import norm 
from statsmodels.tsa.stattools import acf 
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from sklearn.linear_model import LinearRegression

# %%
def sThetaF(y, s_period = 1, h = 10, s = None):
    """
    @param y : array-like time series data
    @param s_period : the no. of observations before seasonal pattern repeats
    @param h : number of period for forcasting
    @s : additive or multiplicative 
    """
    fcast = {} # store result
    n = y.index.size
    x = y.copy()
    m = s_period
    time_y = np.array(np.arange(n))/m + 1
    time_fc = time_y[n-1] + np.array(np.arange(1,h+1))/m

    s_type = 'multiplicative'
    if s is not None:
        if s == 'additive':
            s = True
            s_type = 'additive'

    # Seasonality Test & Decomposition
    if s is not None and m >= 4:
        r = (acf(x, nlags = m+1))[1:]
        clim = 1.64/sqrt(n) * np.sqrt(np.cumsum([1, 2 * np.square(r)]))
        s = abs(r[m-1]) > clim[m-1]
    else:
        if not s:
            s = False


    if s: 
        decomp = seasonal_decompose(x, model = s_type)
        if s_type == 'additive' or (s_type -- 'multiplicative' and any(decomp < 0.01)): 
            s_type = 'additive'
            decomp = seasonal_decompose(x, model = 'additive').seasonal
            x = x - decomp
        else:
            x = x/decomp


    ## Find Theta Line
    model = LinearRegression().fit(time_y.reshape(-1,1), x)
    fcast['mean'] = model.intercept_ + model.coef_ * time_fc 

    return fcast

# %%
stv_df = pd.read_csv('./data/sales_train_validation.csv')
stv_df['time_series'] = stv_df[[f'd_{i}' for i in range(1241,1914)]].values.tolist()
index = [f'd_{i}' for i in range(1241,1914)]
test_series = pd.Series(stv_df['time_series'].iloc[0], index)
pred = sThetaF(test_series, s_period = 28, h = 28)['mean']
for i in range(1, 30490):
    test_series = pd.Series(stv_df['time_series'].iloc[i], index)
    y_pred = sThetaF(test_series, s_period = 28, h = 28)['mean']
    pred = np.vstack((pred, y_pred)) 

pred = np.vstack((pred, np.zeros((30490, 28))))
columns = [f'F{i}' for i in range(1,29)]
final = pd.DataFrame(pred, columns=columns)
subm = pd.read_csv('./data/sample_submission.csv')
final['id'] = subm['id']
final = final.set_index('id')

# %%
final
# Out:
#                                       F1         F2         F3         F4  \
# id
# HOBBIES_1_001_CA_1_validation   0.818788   0.819230   0.819671   0.820112
# HOBBIES_1_002_CA_1_validation   0.306901   0.306829   0.306756   0.306684
# HOBBIES_1_003_CA_1_validation   0.701629   0.702627   0.703624   0.704621
# HOBBIES_1_004_CA_1_validation   1.784228   1.783059   1.781890   1.780720
# HOBBIES_1_005_CA_1_validation   1.249469   1.249897   1.250324   1.250751
# HOBBIES_1_006_CA_1_validation   0.413805   0.412436   0.411067   0.409698
# HOBBIES_1_007_CA_1_validation   0.306809   0.306846   0.306883   0.306921
# HOBBIES_1_008_CA_1_validation  10.032822  10.034798  10.036774  10.038749
# HOBBIES_1_009_CA_1_validation   0.023668   0.022032   0.020396   0.018760
# HOBBIES_1_010_CA_1_validation   0.525937   0.525610   0.525284   0.524957
# HOBBIES_1_011_CA_1_validation   0.118526   0.118670   0.118815   0.118959
# HOBBIES_1_012_CA_1_validation   0.153988   0.153709   0.153429   0.153150
# HOBBIES_1_013_CA_1_validation   0.335677   0.335602   0.335526   0.335451
# HOBBIES_1_014_CA_1_validation   1.832838   1.833149   1.833460   1.833771
# HOBBIES_1_015_CA_1_validation   2.536285   2.530085   2.523886   2.517686
# HOBBIES_1_016_CA_1_validation   6.050719   6.050684   6.050650   6.050615
# HOBBIES_1_017_CA_1_validation   0.976305   0.975927   0.975548   0.975169
# HOBBIES_1_018_CA_1_validation   0.094898   0.094968   0.095037   0.095107
# HOBBIES_1_019_CA_1_validation   6.240183   6.236151   6.232119   6.228088
# HOBBIES_1_020_CA_1_validation   0.293754   0.293788   0.293822   0.293856
# HOBBIES_1_021_CA_1_validation   0.831060   0.831282   0.831504   0.831726
# HOBBIES_1_022_CA_1_validation   0.362012   0.362455   0.362899   0.363343
# HOBBIES_1_023_CA_1_validation   1.313415   1.315196   1.316977   1.318758
# HOBBIES_1_024_CA_1_validation   0.115435   0.114922   0.114409   0.113896
# HOBBIES_1_025_CA_1_validation   0.598121   0.598084   0.598047   0.598009
# HOBBIES_1_026_CA_1_validation   0.093319   0.093521   0.093723   0.093925
# HOBBIES_1_027_CA_1_validation   0.603242   0.603741   0.604239   0.604737
# HOBBIES_1_028_CA_1_validation   0.894608   0.896192   0.897775   0.899358
# HOBBIES_1_029_CA_1_validation   2.153152   2.154453   2.155754   2.157055
# HOBBIES_1_030_CA_1_validation   6.657928   6.663284   6.668641   6.673997
# ...                                  ...        ...        ...        ...
# FOODS_3_798_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_799_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_800_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_801_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_802_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_803_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_804_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_805_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_806_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_807_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_808_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_809_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_810_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_811_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_812_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_813_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_814_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_815_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_816_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_817_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_818_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_819_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_820_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_821_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_822_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_823_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_824_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_825_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_826_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_827_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
#
#                                       F5         F6         F7         F8  \
# id
# HOBBIES_1_001_CA_1_validation   0.820553   0.820994   0.821435   0.821876
# HOBBIES_1_002_CA_1_validation   0.306611   0.306539   0.306466   0.306394
# HOBBIES_1_003_CA_1_validation   0.705619   0.706616   0.707613   0.708611
# HOBBIES_1_004_CA_1_validation   1.779551   1.778382   1.777212   1.776043
# HOBBIES_1_005_CA_1_validation   1.251178   1.251605   1.252033   1.252460
# HOBBIES_1_006_CA_1_validation   0.408329   0.406960   0.405591   0.404222
# HOBBIES_1_007_CA_1_validation   0.306958   0.306996   0.307033   0.307070
# HOBBIES_1_008_CA_1_validation  10.040725  10.042701  10.044676  10.046652
# HOBBIES_1_009_CA_1_validation   0.017124   0.015487   0.013851   0.012215
# HOBBIES_1_010_CA_1_validation   0.524631   0.524304   0.523978   0.523651
# HOBBIES_1_011_CA_1_validation   0.119104   0.119248   0.119393   0.119537
# HOBBIES_1_012_CA_1_validation   0.152870   0.152591   0.152312   0.152032
# HOBBIES_1_013_CA_1_validation   0.335376   0.335300   0.335225   0.335150
# HOBBIES_1_014_CA_1_validation   1.834081   1.834392   1.834703   1.835014
# HOBBIES_1_015_CA_1_validation   2.511486   2.505287   2.499087   2.492887
# HOBBIES_1_016_CA_1_validation   6.050580   6.050546   6.050511   6.050476
# HOBBIES_1_017_CA_1_validation   0.974790   0.974411   0.974032   0.973653
# HOBBIES_1_018_CA_1_validation   0.095177   0.095247   0.095317   0.095387
# HOBBIES_1_019_CA_1_validation   6.224056   6.220025   6.215993   6.211962
# HOBBIES_1_020_CA_1_validation   0.293890   0.293924   0.293958   0.293992
# HOBBIES_1_021_CA_1_validation   0.831947   0.832169   0.832391   0.832613
# HOBBIES_1_022_CA_1_validation   0.363787   0.364230   0.364674   0.365118
# HOBBIES_1_023_CA_1_validation   1.320539   1.322320   1.324101   1.325882
# HOBBIES_1_024_CA_1_validation   0.113383   0.112870   0.112358   0.111845
# HOBBIES_1_025_CA_1_validation   0.597972   0.597935   0.597897   0.597860
# HOBBIES_1_026_CA_1_validation   0.094127   0.094329   0.094531   0.094733
# HOBBIES_1_027_CA_1_validation   0.605235   0.605733   0.606231   0.606729
# HOBBIES_1_028_CA_1_validation   0.900941   0.902524   0.904108   0.905691
# HOBBIES_1_029_CA_1_validation   2.158356   2.159657   2.160958   2.162259
# HOBBIES_1_030_CA_1_validation   6.679353   6.684709   6.690065   6.695421
# ...                                  ...        ...        ...        ...
# FOODS_3_798_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_799_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_800_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_801_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_802_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_803_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_804_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_805_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_806_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_807_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_808_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_809_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_810_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_811_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_812_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_813_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_814_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_815_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_816_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_817_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_818_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_819_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_820_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_821_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_822_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_823_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_824_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_825_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_826_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_827_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
#
#                                       F9        F10  ...        F19  \
# id                                                   ...
# HOBBIES_1_001_CA_1_validation   0.822317   0.822758  ...   0.826728
# HOBBIES_1_002_CA_1_validation   0.306321   0.306248  ...   0.305595
# HOBBIES_1_003_CA_1_validation   0.709608   0.710605  ...   0.719581
# HOBBIES_1_004_CA_1_validation   1.774873   1.773704  ...   1.763180
# HOBBIES_1_005_CA_1_validation   1.252887   1.253314  ...   1.257159
# HOBBIES_1_006_CA_1_validation   0.402853   0.401484  ...   0.389162
# HOBBIES_1_007_CA_1_validation   0.307108   0.307145  ...   0.307482
# HOBBIES_1_008_CA_1_validation  10.048628  10.050603  ...  10.068385
# HOBBIES_1_009_CA_1_validation   0.010579   0.008943  ...  -0.005782
# HOBBIES_1_010_CA_1_validation   0.523325   0.522998  ...   0.520060
# HOBBIES_1_011_CA_1_validation   0.119682   0.119826  ...   0.121126
# HOBBIES_1_012_CA_1_validation   0.151753   0.151473  ...   0.148959
# HOBBIES_1_013_CA_1_validation   0.335074   0.334999  ...   0.334321
# HOBBIES_1_014_CA_1_validation   1.835325   1.835636  ...   1.838433
# HOBBIES_1_015_CA_1_validation   2.486688   2.480488  ...   2.424692
# HOBBIES_1_016_CA_1_validation   6.050442   6.050407  ...   6.050095
# HOBBIES_1_017_CA_1_validation   0.973274   0.972895  ...   0.969484
# HOBBIES_1_018_CA_1_validation   0.095457   0.095527  ...   0.096157
# HOBBIES_1_019_CA_1_validation   6.207930   6.203899  ...   6.167615
# HOBBIES_1_020_CA_1_validation   0.294025   0.294059  ...   0.294365
# HOBBIES_1_021_CA_1_validation   0.832835   0.833056  ...   0.835053
# HOBBIES_1_022_CA_1_validation   0.365561   0.366005  ...   0.369999
# HOBBIES_1_023_CA_1_validation   1.327663   1.329444  ...   1.345473
# HOBBIES_1_024_CA_1_validation   0.111332   0.110819  ...   0.106204
# HOBBIES_1_025_CA_1_validation   0.597823   0.597786  ...   0.597450
# HOBBIES_1_026_CA_1_validation   0.094934   0.095136  ...   0.096954
# HOBBIES_1_027_CA_1_validation   0.607228   0.607726  ...   0.612209
# HOBBIES_1_028_CA_1_validation   0.907274   0.908857  ...   0.923106
# HOBBIES_1_029_CA_1_validation   2.163560   2.164861  ...   2.176570
# HOBBIES_1_030_CA_1_validation   6.700778   6.706134  ...   6.754339
# ...                                  ...        ...  ...        ...
# FOODS_3_798_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_799_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_800_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_801_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_802_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_803_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_804_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_805_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_806_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_807_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_808_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_809_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_810_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_811_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_812_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_813_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_814_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_815_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_816_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_817_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_818_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_819_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_820_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_821_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_822_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_823_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_824_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_825_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_826_WI_3_evaluation     0.000000   0.000000  ...   0.000000
# FOODS_3_827_WI_3_evaluation     0.000000   0.000000  ...   0.000000
#
#                                      F20        F21        F22        F23  \
# id
# HOBBIES_1_001_CA_1_validation   0.827170   0.827611   0.828052   0.828493
# HOBBIES_1_002_CA_1_validation   0.305523   0.305450   0.305378   0.305305
# HOBBIES_1_003_CA_1_validation   0.720579   0.721576   0.722573   0.723571
# HOBBIES_1_004_CA_1_validation   1.762010   1.760841   1.759672   1.758502
# HOBBIES_1_005_CA_1_validation   1.257586   1.258014   1.258441   1.258868
# HOBBIES_1_006_CA_1_validation   0.387793   0.386424   0.385055   0.383686
# HOBBIES_1_007_CA_1_validation   0.307519   0.307557   0.307594   0.307631
# HOBBIES_1_008_CA_1_validation  10.070360  10.072336  10.074312  10.076287
# HOBBIES_1_009_CA_1_validation  -0.007418  -0.009054  -0.010690  -0.012326
# HOBBIES_1_010_CA_1_validation   0.519734   0.519407   0.519081   0.518754
# HOBBIES_1_011_CA_1_validation   0.121271   0.121415   0.121560   0.121704
# HOBBIES_1_012_CA_1_validation   0.148680   0.148400   0.148121   0.147841
# HOBBIES_1_013_CA_1_validation   0.334246   0.334170   0.334095   0.334019
# HOBBIES_1_014_CA_1_validation   1.838744   1.839055   1.839366   1.839677
# HOBBIES_1_015_CA_1_validation   2.418492   2.412292   2.406093   2.399893
# HOBBIES_1_016_CA_1_validation   6.050060   6.050025   6.049991   6.049956
# HOBBIES_1_017_CA_1_validation   0.969105   0.968726   0.968347   0.967969
# HOBBIES_1_018_CA_1_validation   0.096227   0.096297   0.096367   0.096437
# HOBBIES_1_019_CA_1_validation   6.163583   6.159552   6.155520   6.151489
# HOBBIES_1_020_CA_1_validation   0.294399   0.294433   0.294467   0.294501
# HOBBIES_1_021_CA_1_validation   0.835274   0.835496   0.835718   0.835940
# HOBBIES_1_022_CA_1_validation   0.370442   0.370886   0.371330   0.371773
# HOBBIES_1_023_CA_1_validation   1.347254   1.349035   1.350816   1.352597
# HOBBIES_1_024_CA_1_validation   0.105691   0.105178   0.104665   0.104152
# HOBBIES_1_025_CA_1_validation   0.597412   0.597375   0.597338   0.597300
# HOBBIES_1_026_CA_1_validation   0.097156   0.097358   0.097560   0.097762
# HOBBIES_1_027_CA_1_validation   0.612707   0.613206   0.613704   0.614202
# HOBBIES_1_028_CA_1_validation   0.924689   0.926272   0.927856   0.929439
# HOBBIES_1_029_CA_1_validation   2.177871   2.179172   2.180474   2.181775
# HOBBIES_1_030_CA_1_validation   6.759696   6.765052   6.770408   6.775764
# ...                                  ...        ...        ...        ...
# FOODS_3_798_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_799_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_800_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_801_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_802_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_803_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_804_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_805_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_806_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_807_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_808_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_809_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_810_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_811_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_812_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_813_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_814_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_815_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_816_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_817_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_818_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_819_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_820_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_821_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_822_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_823_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_824_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_825_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_826_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_827_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
#
#                                      F24        F25        F26        F27  \
# id
# HOBBIES_1_001_CA_1_validation   0.828934   0.829375   0.829816   0.830257
# HOBBIES_1_002_CA_1_validation   0.305233   0.305160   0.305088   0.305015
# HOBBIES_1_003_CA_1_validation   0.724568   0.725565   0.726563   0.727560
# HOBBIES_1_004_CA_1_validation   1.757333   1.756164   1.754994   1.753825
# HOBBIES_1_005_CA_1_validation   1.259295   1.259722   1.260150   1.260577
# HOBBIES_1_006_CA_1_validation   0.382317   0.380948   0.379578   0.378209
# HOBBIES_1_007_CA_1_validation   0.307669   0.307706   0.307744   0.307781
# HOBBIES_1_008_CA_1_validation  10.078263  10.080239  10.082214  10.084190
# HOBBIES_1_009_CA_1_validation  -0.013963  -0.015599  -0.017235  -0.018871
# HOBBIES_1_010_CA_1_validation   0.518428   0.518101   0.517775   0.517448
# HOBBIES_1_011_CA_1_validation   0.121849   0.121993   0.122138   0.122282
# HOBBIES_1_012_CA_1_validation   0.147562   0.147283   0.147003   0.146724
# HOBBIES_1_013_CA_1_validation   0.333944   0.333869   0.333793   0.333718
# HOBBIES_1_014_CA_1_validation   1.839987   1.840298   1.840609   1.840920
# HOBBIES_1_015_CA_1_validation   2.393693   2.387494   2.381294   2.375095
# HOBBIES_1_016_CA_1_validation   6.049921   6.049887   6.049852   6.049817
# HOBBIES_1_017_CA_1_validation   0.967590   0.967211   0.966832   0.966453
# HOBBIES_1_018_CA_1_validation   0.096507   0.096577   0.096646   0.096716
# HOBBIES_1_019_CA_1_validation   6.147457   6.143426   6.139394   6.135363
# HOBBIES_1_020_CA_1_validation   0.294534   0.294568   0.294602   0.294636
# HOBBIES_1_021_CA_1_validation   0.836162   0.836383   0.836605   0.836827
# HOBBIES_1_022_CA_1_validation   0.372217   0.372661   0.373105   0.373548
# HOBBIES_1_023_CA_1_validation   1.354378   1.356159   1.357940   1.359721
# HOBBIES_1_024_CA_1_validation   0.103639   0.103126   0.102614   0.102101
# HOBBIES_1_025_CA_1_validation   0.597263   0.597226   0.597188   0.597151
# HOBBIES_1_026_CA_1_validation   0.097964   0.098166   0.098368   0.098570
# HOBBIES_1_027_CA_1_validation   0.614700   0.615198   0.615696   0.616194
# HOBBIES_1_028_CA_1_validation   0.931022   0.932605   0.934188   0.935772
# HOBBIES_1_029_CA_1_validation   2.183076   2.184377   2.185678   2.186979
# HOBBIES_1_030_CA_1_validation   6.781120   6.786476   6.791833   6.797189
# ...                                  ...        ...        ...        ...
# FOODS_3_798_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_799_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_800_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_801_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_802_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_803_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_804_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_805_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_806_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_807_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_808_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_809_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_810_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_811_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_812_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_813_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_814_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_815_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_816_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_817_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_818_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_819_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_820_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_821_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_822_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_823_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_824_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_825_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_826_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
# FOODS_3_827_WI_3_evaluation     0.000000   0.000000   0.000000   0.000000
#
#                                      F28
# id
# HOBBIES_1_001_CA_1_validation   0.830698
# HOBBIES_1_002_CA_1_validation   0.304942
# HOBBIES_1_003_CA_1_validation   0.728557
# HOBBIES_1_004_CA_1_validation   1.752655
# HOBBIES_1_005_CA_1_validation   1.261004
# HOBBIES_1_006_CA_1_validation   0.376840
# HOBBIES_1_007_CA_1_validation   0.307818
# HOBBIES_1_008_CA_1_validation  10.086166
# HOBBIES_1_009_CA_1_validation  -0.020507
# HOBBIES_1_010_CA_1_validation   0.517122
# HOBBIES_1_011_CA_1_validation   0.122427
# HOBBIES_1_012_CA_1_validation   0.146444
# HOBBIES_1_013_CA_1_validation   0.333643
# HOBBIES_1_014_CA_1_validation   1.841231
# HOBBIES_1_015_CA_1_validation   2.368895
# HOBBIES_1_016_CA_1_validation   6.049783
# HOBBIES_1_017_CA_1_validation   0.966074
# HOBBIES_1_018_CA_1_validation   0.096786
# HOBBIES_1_019_CA_1_validation   6.131331
# HOBBIES_1_020_CA_1_validation   0.294670
# HOBBIES_1_021_CA_1_validation   0.837049
# HOBBIES_1_022_CA_1_validation   0.373992
# HOBBIES_1_023_CA_1_validation   1.361502
# HOBBIES_1_024_CA_1_validation   0.101588
# HOBBIES_1_025_CA_1_validation   0.597114
# HOBBIES_1_026_CA_1_validation   0.098772
# HOBBIES_1_027_CA_1_validation   0.616693
# HOBBIES_1_028_CA_1_validation   0.937355
# HOBBIES_1_029_CA_1_validation   2.188280
# HOBBIES_1_030_CA_1_validation   6.802545
# ...                                  ...
# FOODS_3_798_WI_3_evaluation     0.000000
# FOODS_3_799_WI_3_evaluation     0.000000
# FOODS_3_800_WI_3_evaluation     0.000000
# FOODS_3_801_WI_3_evaluation     0.000000
# FOODS_3_802_WI_3_evaluation     0.000000
# FOODS_3_803_WI_3_evaluation     0.000000
# FOODS_3_804_WI_3_evaluation     0.000000
# FOODS_3_805_WI_3_evaluation     0.000000
# FOODS_3_806_WI_3_evaluation     0.000000
# FOODS_3_807_WI_3_evaluation     0.000000
# FOODS_3_808_WI_3_evaluation     0.000000
# FOODS_3_809_WI_3_evaluation     0.000000
# FOODS_3_810_WI_3_evaluation     0.000000
# FOODS_3_811_WI_3_evaluation     0.000000
# FOODS_3_812_WI_3_evaluation     0.000000
# FOODS_3_813_WI_3_evaluation     0.000000
# FOODS_3_814_WI_3_evaluation     0.000000
# FOODS_3_815_WI_3_evaluation     0.000000
# FOODS_3_816_WI_3_evaluation     0.000000
# FOODS_3_817_WI_3_evaluation     0.000000
# FOODS_3_818_WI_3_evaluation     0.000000
# FOODS_3_819_WI_3_evaluation     0.000000
# FOODS_3_820_WI_3_evaluation     0.000000
# FOODS_3_821_WI_3_evaluation     0.000000
# FOODS_3_822_WI_3_evaluation     0.000000
# FOODS_3_823_WI_3_evaluation     0.000000
# FOODS_3_824_WI_3_evaluation     0.000000
# FOODS_3_825_WI_3_evaluation     0.000000
# FOODS_3_826_WI_3_evaluation     0.000000
# FOODS_3_827_WI_3_evaluation     0.000000
#
# [60980 rows x 28 columns]
